# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Wed Nov 18 05:18:16 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !gdown --id 1F7NtdP8qiVDJG4THmBQ6DrEB3WcANmi7
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1F7NtdP8qiVDJG4THmBQ6DrEB3WcANmi7
# To: /content/intention_repeater_max_cuda.cu
# 100% 17.0k/17.0k [00:00<00:00, 25.5MB/s]

# %%
# !nvcc intention_repeater_max_cuda.cu -O3 -o intention_repeater_max_cuda

# %%
# !/content/intention_repeater_max_cuda --gpu 0 --dur 00:00:01 --rate Average --imem 0.1 --intent "Send love to Gaia."
# Out:
# Intention Repeater MAX CUDA v2.2 created by Thomas Sweet aka Anthro Teacher.
# CUDA and flags functionality by Karteek Sheri.
# Intention multiplying functionality by Thomas Sweet.
# Supportive energies by NotFrank.
# This software comes with no guarantees or warranty of any kind and is for entertainment purposes only.
# Press Ctrl-C to quit.
#
# Loading intention into memory.
# GPU 0 is selected.
# [00:00:01] (3.802q / 3.802PHz): Send love to Gaia.
